# %%
import pandas as pd

from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %% [markdown]
# # 1. 샘플 데이터셋을 생성

# %%
dataset = [['Onion', 'Potato', 'Burger'],
           ['Potato', 'Burger', 'Milk'],
           ['Milk', 'Beer'],
           ['Potato', 'Milk'],
           ['Onion', 'Potato', 'Burger', 'Beer'],
           ['Onion', 'Potato', 'Burger', 'Milk']
          ]

# %%
dataset
# Out:
# [['Onion', 'Potato', 'Burger'],
#  ['Potato', 'Burger', 'Milk'],
#  ['Milk', 'Beer'],
#  ['Potato', 'Milk'],
#  ['Onion', 'Potato', 'Burger', 'Beer'],
#  ['Onion', 'Potato', 'Burger', 'Milk']]

# %% [markdown]
# # 2.  아래 코드는 아래의 표 데이터 순서대로 포함되어 있으면 True, 없으면 False를 저장한 값으로 인코딩함
# |Beer|Burger|Milk|Onion|Potato|
# |:--:|:--:|:--:|:--:|:--:|
# |3행, 5행|1행, 2행, 5행, 6행|2행, 3행, 4행, 6행|1행, 5행, 6행|1행, 2행, 4행, 5행, 6행|

# %%
encode = TransactionEncoder()

encoded_array = encode.fit(dataset).transform(dataset)
encoded_array
# Out:
# array([[False,  True, False,  True,  True],
#        [False,  True,  True, False,  True],
#        [ True, False,  True, False, False],
#        [False, False,  True, False,  True],
#        [ True,  True, False,  True,  True],
#        [False,  True,  True,  True,  True]])

# %% [markdown]
# # 3. 인코딩된 결과를 데이터프레임으로 변환, 이때 열 이름은 각각 인코딩할 때 사용된 컬럼명

# %%
dataframe = pd.DataFrame(encoded_array, columns=encode.columns_)
dataframe
# Out:
#     Beer  Burger   Milk  Onion  Potato
# 0  False    True  False   True    True
# 1  False    True   True  False    True
# 2   True   False   True  False   False
# 3  False   False   True  False    True
# 4   True    True  False   True    True
# 5  False    True   True   True    True

# %% [markdown]
# # 4. 최소 지지도 값이 0.4가 넘는 값만을 사용해서 빈번항목집합을 생성
# - support = P(A∩B)
# - A와 B가 동시에 일어난 횟수 / 전체 거래 횟수

# %%
frequent_itemsets = apriori(dataframe, min_support=0.4, use_colnames=True)
frequent_itemsets
# Out:
#     support                 itemsets
# 0  0.666667                 (Burger)
# 1  0.666667                   (Milk)
# 2  0.500000                  (Onion)
# 3  0.833333                 (Potato)
# 4  0.500000          (Onion, Burger)
# 5  0.666667         (Potato, Burger)
# 6  0.500000           (Potato, Milk)
# 7  0.500000          (Potato, Onion)
# 8  0.500000  (Potato, Onion, Burger)

# %% [markdown]
# # 5. confidence 값이 최소 0.7 이상인 값만 pattern_rules에 담아서 이를 출력
# - confidence = P(A∩B) / P(A)
# - A와 B가 동시에 일어난 횟수 / A가 일어난 횟수

# %%
pattern_rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.7)
pattern_rules
# Out:
#          antecedents       consequents  antecedent support  \
# 0            (Onion)          (Burger)            0.500000
# 1           (Burger)           (Onion)            0.666667
# 2           (Potato)          (Burger)            0.833333
# 3           (Burger)          (Potato)            0.666667
# 4             (Milk)          (Potato)            0.666667
# 5            (Onion)          (Potato)            0.500000
# 6    (Potato, Onion)          (Burger)            0.500000
# 7   (Potato, Burger)           (Onion)            0.666667
# 8    (Onion, Burger)          (Potato)            0.500000
# 9            (Onion)  (Potato, Burger)            0.500000
# 10          (Burger)   (Potato, Onion)            0.666667
#
#     consequent support   support  confidence  lift  leverage  conviction  \
# 0             0.666667  0.500000        1.00   1.5  0.166667         inf
# 1             0.500000  0.500000        0.75   1.5  0.166667    2.000000
# 2             0.666667  0.666667        0.80   1.2  0.111111    1.666667
# 3             0.833333  0.666667        1.00   1.2  0.111111         inf
# 4             0.833333  0.500000        0.75   0.9 -0.055556    0.666667
# 5             0.833333  0.500000        1.00   1.2  0.083333         inf
# 6             0.666667  0.500000        1.00   1.5  0.166667         inf
# 7             0.500000  0.500000        0.75   1.5  0.166667    2.000000
# 8             0.833333  0.500000        1.00   1.2  0.083333         inf
# 9             0.666667  0.500000        1.00   1.5  0.166667         inf
# 10            0.500000  0.500000        0.75   1.5  0.166667    2.000000
#
#     zhangs_metric
# 0        0.666667
# 1        1.000000
# 2        1.000000
# 3        0.500000
# 4       -0.250000
# 5        0.333333
# 6        0.666667
# 7        1.000000
# 8        0.333333
# 9        0.666667
# 10       1.000000

# %% [markdown]
# # Text Mining Practice

# %%
import pandas as pd 
import numpy as np
from pandas import DataFrame
from tqdm import tqdm
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %%
basket = pd.read_csv('./data/Market_Basket_Optimisation.csv')
basket.head()
# Out:
#            shrimp    almonds     avocado    vegetables mix green grapes  \
# 0         burgers  meatballs        eggs               NaN          NaN
# 1         chutney        NaN         NaN               NaN          NaN
# 2          turkey    avocado         NaN               NaN          NaN
# 3   mineral water       milk  energy bar  whole wheat rice    green tea
# 4  low fat yogurt        NaN         NaN               NaN          NaN
#
#   whole weat flour yams cottage cheese energy drink tomato juice  \
# 0              NaN  NaN            NaN          NaN          NaN
# 1              NaN  NaN            NaN          NaN          NaN
# 2              NaN  NaN            NaN          NaN          NaN
# 3              NaN  NaN            NaN          NaN          NaN
# 4              NaN  NaN            NaN          NaN          NaN
#
#   low fat yogurt green tea honey salad mineral water salmon antioxydant juice  \
# 0            NaN       NaN   NaN   NaN           NaN    NaN               NaN
# 1            NaN       NaN   NaN   NaN           NaN    NaN               NaN
# 2            NaN       NaN   NaN   NaN           NaN    NaN               NaN
# 3            NaN       NaN   NaN   NaN           NaN    NaN               NaN
# 4            NaN       NaN   NaN   NaN           NaN    NaN               NaN
#
#   frozen smoothie spinach  olive oil
# 0             NaN     NaN        NaN
# 1             NaN     NaN        NaN
# 2             NaN     NaN        NaN
# 3             NaN     NaN        NaN
# 4             NaN     NaN        NaN

# %% [markdown]
# ## 1. Converting the data frame into a list of lists

# %%
records = [[str(basket.values[i, j]) for j in range(20)] for i in tqdm(range(7501), desc="Processing records")]
# Out:
# Processing records: 100%|██████████████████▉| 7499/7501 [09:47<00:00, 14.44it/s]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 records = [[str(basket.values[i, j]) for j in range(20)] for i in tqdm(range(7501), desc="Processing records")]
#
# Cell In[39], line 1, in <listcomp>(.0)
# ----> 1 records = [[str(basket.values[i, j]) for j in range(20)] for i in tqdm(range(7501), desc="Processing records")]
#
# Cell In[39], line 1, in <listcomp>(.0)
# ----> 1 records = [[str(basket.values[i, j]) for j in range(20)] for i in tqdm(range(7501), desc="Processing records")]
#
# IndexError: index 7500 is out of bounds for axis 0 with size 7500

# %% [markdown]
# ### explanation

# %% [markdown]
# ## 2. Encoding and transforming back to data frame

# %%
encode = TransactionEncoder()
encoded_array = encode.fit(records).transform(records)

data_frame = pd.DataFrame(encoded_array, columns = encode.columns_)
data_frame
# Out:
#       asparagus  almonds  antioxydant juice  asparagus  avocado  babies food  \
# 0         False    False              False      False    False        False
# 1         False    False              False      False    False        False
# 2         False    False              False      False     True        False
# 3         False    False              False      False    False        False
# 4         False    False              False      False    False        False
# ..          ...      ...                ...        ...      ...          ...
# 742       False    False              False      False    False        False
# 743       False    False              False      False    False        False
# 744       False    False              False      False    False        False
# 745       False    False              False      False    False        False
# 746       False    False              False      False    False        False
#
#      bacon  barbecue sauce  black tea  blueberries  ...  toothpaste  turkey  \
# 0    False           False      False        False  ...       False   False
# 1    False           False      False        False  ...       False   False
# 2    False           False      False        False  ...       False    True
# 3    False           False      False        False  ...       False   False
# 4    False           False      False        False  ...       False   False
# ..     ...             ...        ...          ...  ...         ...     ...
# 742  False           False      False        False  ...       False   False
# 743  False           False      False        False  ...       False   False
# 744  False           False      False        False  ...       False   False
# 745  False           False      False        False  ...       False   False
# 746  False           False      False        False  ...       False    True
#
#      vegetables mix  water spray  white wine  whole wheat pasta  \
# 0             False        False       False              False
# 1             False        False       False              False
# 2             False        False       False              False
# 3             False        False       False              False
# 4             False        False       False              False
# ..              ...          ...         ...                ...
# 742           False        False       False              False
# 743           False        False       False              False
# 744           False        False       False              False
# 745           False        False       False              False
# 746           False        False       False              False
#
#      whole wheat rice   yams  yogurt cake  zucchini
# 0               False  False        False     False
# 1               False  False        False     False
# 2               False  False        False     False
# 3                True  False        False     False
# 4               False  False        False     False
# ..                ...    ...          ...       ...
# 742             False  False        False     False
# 743             False  False        False     False
# 744             False  False        False     False
# 745             False  False        False     False
# 746             False  False        False     False
#
# [747 rows x 118 columns]

# %% [markdown]
# ### explanation

# %% [markdown]
# ## 3. Drop missing values

# %%
basket_clean = data_frame.drop(['nan'], axis = 1)
basket_clean
# Out:
#       asparagus  almonds  antioxydant juice  asparagus  avocado  babies food  \
# 0         False    False              False      False    False        False
# 1         False    False              False      False    False        False
# 2         False    False              False      False     True        False
# 3         False    False              False      False    False        False
# 4         False    False              False      False    False        False
# ..          ...      ...                ...        ...      ...          ...
# 742       False    False              False      False    False        False
# 743       False    False              False      False    False        False
# 744       False    False              False      False    False        False
# 745       False    False              False      False    False        False
# 746       False    False              False      False    False        False
#
#      bacon  barbecue sauce  black tea  blueberries  ...  toothpaste  turkey  \
# 0    False           False      False        False  ...       False   False
# 1    False           False      False        False  ...       False   False
# 2    False           False      False        False  ...       False    True
# 3    False           False      False        False  ...       False   False
# 4    False           False      False        False  ...       False   False
# ..     ...             ...        ...          ...  ...         ...     ...
# 742  False           False      False        False  ...       False   False
# 743  False           False      False        False  ...       False   False
# 744  False           False      False        False  ...       False   False
# 745  False           False      False        False  ...       False   False
# 746  False           False      False        False  ...       False    True
#
#      vegetables mix  water spray  white wine  whole wheat pasta  \
# 0             False        False       False              False
# 1             False        False       False              False
# 2             False        False       False              False
# 3             False        False       False              False
# 4             False        False       False              False
# ..              ...          ...         ...                ...
# 742           False        False       False              False
# 743           False        False       False              False
# 744           False        False       False              False
# 745           False        False       False              False
# 746           False        False       False              False
#
#      whole wheat rice   yams  yogurt cake  zucchini
# 0               False  False        False     False
# 1               False  False        False     False
# 2               False  False        False     False
# 3                True  False        False     False
# 4               False  False        False     False
# ..                ...    ...          ...       ...
# 742             False  False        False     False
# 743             False  False        False     False
# 744             False  False        False     False
# 745             False  False        False     False
# 746             False  False        False     False
#
# [747 rows x 117 columns]

# %% [markdown]
# ### explanation

# %% [markdown]
# ## 4. Train with Apriori

# %%
frequent_itemsets = apriori(basket_clean, min_support = 0.04, use_colnames = True)
frequent_itemsets.head()
# Out:
#     support     itemsets
# 0  0.080321    (burgers)
# 1  0.072289       (cake)
# 2  0.042838  (champagne)
# 3  0.061580    (chicken)
# 4  0.187416  (chocolate)

# %% [markdown]
# ### explanation

# %% [markdown]
# ## 5. Creating rules

# %%
pattern_rules = association_rules(frequent_itemsets, metric = 'confidence', min_threshold = 0.3)
pattern_rules
# Out:
#       antecedents      consequents  antecedent support  consequent support  \
# 0          (milk)      (chocolate)            0.124498            0.187416
# 1     (chocolate)  (mineral water)            0.187416            0.261044
# 2  (french fries)           (eggs)            0.157965            0.230254
# 3          (eggs)  (mineral water)            0.230254            0.261044
# 4   (ground beef)  (mineral water)            0.101740            0.261044
# 5          (milk)  (mineral water)            0.124498            0.261044
# 6     (spaghetti)  (mineral water)            0.180723            0.261044
#
#     support  confidence      lift  leverage  conviction  zhangs_metric
# 0  0.045515    0.365591  1.950691  0.022182    1.280852       0.556665
# 1  0.066934    0.357143  1.368132  0.018010    1.149487       0.331137
# 2  0.050870    0.322034  1.398601  0.014498    1.135375       0.338465
# 3  0.069612    0.302326  1.158140  0.009505    1.059170       0.177391
# 4  0.045515    0.447368  1.713765  0.018957    1.337158       0.463663
# 5  0.049531    0.397849  1.524069  0.017032    1.227194       0.392760
# 6  0.064257    0.355556  1.362051  0.017080    1.146656       0.324449

# %% [markdown]
# ### explanation
